# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '9',
#          '24H_fluctate_rate': '3.18',
#          'average_price': '289.9562',
#          'buy_price': '290',
#          'closing_price': '292',
#          'max_price': '310',
#          'min_price': '268',
#          'opening_price': '283',
#          'sell_price': '293',
#          'units_traded': '1460310.93142696',
#          'volume_1day': '1460310.93142696',
#          'volume_7day': '13411047.844175701627447568'},
#  'ADA': {'24H_fluctate': '0.89',
#          '24H_fluctate_rate': '1.01',
#          'average_price': '89.6494',
#          'buy_price': '89.8',
#          'closing_price': '89.8',
#          'max_price': '93',
#          'min_price': '83.4',
#          'opening_price': '88.9',
#          'sell_price': '89.9',
#          'units_traded': '10364520.10951112',
#          'volume_1day': '10364520.10951112',
#          'volume_7day': '64501649.53975022'},
#  'AE': {'24H_fluctate': '2',
#         '24H_fluctate_rate': '0.42',
#         'average_price': '467.9265',
#         'buy_price': '466',
#         'closing_price': '471',
#         'max_price': '482',
#         'min_price': '440',
#         'opening_price': '469',
#         'sell_price': '470',
#         'units_traded': '247976.89333308',
#         'volume_1day': '247976.89333308',
#         'volume_7day': '2167830.418402428431283062'},
#  'AMO': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-1.63',
#          'average_price': '0.6019',
#          'buy_price': '0.6',
#          'closing_price': '0.6',
#          'max_price': '0.62',
#          'min_price': '0.57',
#          'opening_price': '0.61',
#          'sell_price': '0.61',
#          'units_traded': '248757679.79667096',
#          'volume_1day': '248757679.79667096',
#          'volume_7day': '2050930974.521633935513427205'},
#  'ANKR': {'24H_fluctate': '1.2',
#           '24H_fluctate_rate': '11.53',
#           'average_price': '11.2963',
#           'buy_price': '11.4',
#           'closing_price': '11.6',
#           'max_price': '12.2',
#           'min_price': '10.2',
#           'opening_price': '10.4',
#           'sell_price': '11.6',
#           'units_traded': '53291657.88918497',
#           'volume_1day': '53291657.88918497',
#           'volume_7day': '591668574.137221226010249127'},
#  'APIS': {'24H_fluctate': '0.08',
#           '24H_fluctate_rate': '4.76',
#           'average_price': '1.713',
#           'buy_price': '1.74',
#           'closing_price': '1.76',
#           'max_price': '1.77',
#           'min_price': '1.66',
#           'opening_price': '1.68',
#           'sell_price': '1.76',
#           'units_traded': '22954235.47468717',
#           'volume_1day': '22954235.47468717',
#           'volume_7day': '298064433.232002953763348036'},
#  'ARN': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.63',
#          'average_price': '492.2446',
#          'buy_price': '481',
#          'closing_price': '479',
#          'max_price': '515',
#          'min_price': '457',
#          'opening_price': '476',
#          'sell_price': '489',
#          'units_traded': '190770.157',
#          'volume_1day': '190770.157',
#          'volume_7day': '1723959.4996001'},
#  'AUTO': {'24H_fluctate': '0.01',
#           '24H_fluctate_rate': '0.66',
#           'average_price': '1.5077',
#           'buy_price': '1.5',
#           'closing_price': '1.51',
#           'max_price': '1.53',
#           'min_price': '1.46',
#           'opening_price': '1.5',
#           'sell_price': '1.51',
#           'units_traded': '30688347.78820424',
#           'volume_1day': '30688347.78820424',
#           'volume_7day': '249067538.897875998311957613'},
#  'BAT': {'24H_fluctate': '32',
#          '24H_fluctate_rate': '12.07',
#          'average_price': '295.3282',
#          'buy_price': '294',
#          'closing_price': '297',
#          'max_price': '319',
#          'min_price': '254',
#          'opening_price': '265',
#          'sell_price': '298',
#          'units_traded': '2626372.41205937',
#          'volume_1day': '2626372.41205937',
#          'volume_7day': '8765981.616909141023091944'},
#  'BCD': {'24H_fluctate': '31',
#          '24H_fluctate_rate': '1.56',
#          'average_price': '2006.1201',
#          'buy_price': '1964',
#          'closing_price': '2008',
#          'max_price': '2081',
#          'min_price': '1881',
#          'opening_price': '1977',
#          'sell_price': '2006',
#          'units_traded': '148654.40949293',
#          'volume_1day': '148654.40949293',
#          'volume_7day': '1585693.18454651'},
#  'BCH': {'24H_fluctate': '8200',
#          '24H_fluctate_rate': '2.30',
#          'average_price': '364438.5148',
#          'buy_price': '363500',
#          'closing_price': '364100',
#          'max_price': '382400',
#          'min_price': '339100',
#          'opening_price': '355900',
#          'sell_price': '364100',
#          'units_traded': '43693.21748056',
#          'volume_1day': '43693.21748056',
#          'volume_7day': '250821.23460715'},
#  'BHP': {'24H_fluctate': '-25',
#          '24H_fluctate_rate': '-1.43',
#          'average_price': '1766.2222',
#          'buy_price': '1721',
#          'closing_price': '1723',
#          'max_price': '1815',
#          'min_price': '1690',
#          'opening_price': '1748',
#          'sell_price': '1723',
#          'units_traded': '122727.13167434',
#          'volume_1day': '122727.13167434',
#          'volume_7day': '1690514.43975941'},
#  'BSV': {'24H_fluctate': '6300',
#          '24H_fluctate_rate': '4.14',
#          'average_price': '155958.8008',
#          'buy_price': '158200',
#          'closing_price': '158200',
#          'max_price': '164900',
#          'min_price': '143200',
#          'opening_price': '151900',
#          'sell_price': '158700',
#          'units_traded': '49854.34636964',
#          'volume_1day': '49854.34636964',
#          'volume_7day': '421468.45346467'},
#  'BTC': {'24H_fluctate': '645000',
#          '24H_fluctate_rate': '5.52',
#          'average_price': '12221346.8657',
#          'buy_price': '12319000',
#          'closing_price': '12319000',
#          'max_price': '12800000',
#          'min_price': '11093000',
#          'opening_price': '11674000',
#          'sell_price': '12327000',
#          'units_traded': '16433.31801173',
#          'volume_1day': '16433.31801173',
#          'volume_7day': '93308.52488892'},
#  'BTG': {'24H_fluctate': '-320',
#          '24H_fluctate_rate': '-1.09',
#          'average_price': '29045.1668',
#          'buy_price': '28800',
#          'closing_price': '29000',
#          'max_price': '29610',
#          'min_price': '27790',
#          'opening_price': '29320',
#          'sell_price': '28990',
#          'units_traded': '16405.19799205',
#          'volume_1day': '16405.19799205',
#          'volume_7day': '146971.29115792'},
#  'BTT': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '0.80',
#          'average_price': '1.2472',
#          'buy_price': '1.24',
#          'closing_price': '1.25',
#          'max_price': '1.3',
#          'min_price': '1.15',
#          'opening_price': '1.24',
#          'sell_price': '1.26',
#          'units_traded': '357926569.02139263',
#          'volume_1day': '357926569.02139263',
#          'volume_7day': '1891604507.4768823'},
#  'BZNT': {'24H_fluctate': '-0.6',
#           '24H_fluctate_rate': '-2.75',
#           'average_price': '21.339',
#           'buy_price': '20.9',
#           'closing_price': '21.2',
#           'max_price': '22',
#           'min_price': '20.6',
#           'opening_price': '21.8',
#           'sell_price': '21.1',
#           'units_traded': '8371259.88055998',
#           'volume_1day': '8371259.88055998',
#           'volume_7day': '52735163.346686763134794165'},
#  'CMT': {'24H_fluctate': '1.3',
#          '24H_fluctate_rate': '2.40',
#          'average_price': '53.758',
#          'buy_price': '55.2',
#          'closing_price': '55.4',
#          'max_price': '56.8',
#          'min_price': '50.2',
#          'opening_price': '54.1',
#          'sell_price': '55.4',
#          'units_traded': '13429919.28207726',
#          'volume_1day': '13429919.28207726',
#          'volume_7day': '109261333.980031488679936114'},
#  'CON': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '12.3781',
#          'buy_price': '12.1',
#          'closing_price': '12.2',
#          'max_price': '13',
#          'min_price': '11.8',
#          'opening_price': '12.2',
#          'sell_price': '12.2',
#          'units_traded': '95476534.47789508',
#          'volume_1day': '95476534.47789508',
#          'volume_7day': '739340546.244384724880429395'},
#  'CTXC': {'24H_fluctate': '-1',
#           '24H_fluctate_rate': '-0.24',
#           'average_price': '408',
#           'buy_price': '408',
#           'closing_price': '410',
#           'max_price': '426',
#           'min_price': '355',
#           'opening_price': '411',
#           'sell_price': '410',
#           'units_traded': '897097.64572048',
#           'volume_1day': '897097.64572048',
#           'volume_7day': '5130391.522968887799613788'},
#  'DAC': {'24H_fluctate': '0.22',
#          '24H_fluctate_rate': '3.76',
#          'average_price': '5.9436',
#          'buy_price': '6.06',
#          'closing_price': '6.07',
#          'max_price': '6.14',
#          'min_price': '5.74',
#          'opening_price': '5.85',
#          'sell_price': '6.07',
#          'units_traded': '35067245.98022812',
#          'volume_1day': '35067245.98022812',
#          'volume_7day': '329929785.021620524198057612'},
#  'DACC': {'24H_fluctate': '0.01',
#           '24H_fluctate_rate': '6.66',
#           'average_price': '0.1543',
#           'buy_price': '0.15',
#           'closing_price': '0.16',
#           'max_price': '0.16',
#           'min_price': '0.15',
#           'opening_price': '0.15',
#           'sell_price': '0.16',
#           'units_traded': '200722255.9322',
#           'volume_1day': '200722255.9322',
#           'volume_7day': '3269589097.37746793'},
#  'DASH': {'24H_fluctate': '3600',
#           '24H_fluctate_rate': '2.48',
#           'average_price': '150536.54',
#           'buy_price': '147900',
#           'closing_price': '148700',
#           'max_price': '153000',
#           'min_price': '137000',
#           'opening_price': '145100',
#           'sell_price': '148700',
#           'units_traded': '2809315.74486892',
#           'volume_1day': '2809315.74486892',
#           'volume_7day': '11845116.94663785'},
#  'ELF': {'24H_fluctate': '14',
#          '24H_fluctate_rate': '9.92',
#          'average_price': '151.0271',
#          'buy_price': '153',
#          'closing_price': '155',
#          'max_price': '163',
#          'min_price': '136',
#          'opening_price': '141',
#          'sell_price': '155',
#          'units_traded': '1784264.21469946',
#          'volume_1day': '1784264.21469946',
#          'volume_7day': '9027724.166859304835926065'},
#  'ENJ': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.98',
#          'average_price': '102.505',
#          'buy_price': '101',
#          'closing_price': '103',
#          'max_price': '109',
#          'min_price': '97.1',
#          'opening_price': '101',
#          'sell_price': '103',
#          'units_traded': '12260302.05721828',
#          'volume_1day': '12260302.05721828',
#          'volume_7day': '105387419.5446382021330973'},
#  'EOS': {'24H_fluctate': '119',
#          '24H_fluctate_rate': '2.55',
#          'average_price': '4797.554',
#          'buy_price': '4765',
#          'closing_price': '4772',
#          'max_price': '5000',
#          'min_price': '4490',
#          'opening_price': '4653',
#          'sell_price': '4772',
#          'units_traded': '3152579.37238002',
#          'volume_1day': '3152579.37238002',
#          'volume_7day': '20067252.50713156'},
#  'ETC': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-0.07',
#          'average_price': '6932.0071',
#          'buy_price': '6865',
#          'closing_price': '6860',
#          'max_price': '7215',
#          'min_price': '6500',
#          'opening_price': '6865',
#          'sell_price': '6890',
#          'units_traded': '157908.83373593',
#          'volume_1day': '157908.83373593',
#          'volume_7day': '1007757.936760487927798527'},
#  'ETH': {'24H_fluctate': '700',
#          '24H_fluctate_rate': '0.27',
#          'average_price': '261995.2234',
#          'buy_price': '258900',
#          'closing_price': '259000',
#          'max_price': '273400',
#          'min_price': '246000',
#          'opening_price': '258300',
#          'sell_price': '259300',
#          'units_traded': '109647.66213775',
#          'volume_1day': '109647.66213775',
#          'volume_7day': '718394.998377908782475258'},
#  'ETHOS': {'24H_fluctate': '2',
#            '24H_fluctate_rate': '1.45',
#            'average_price': '138.8134',
#            'buy_price': '138',
#            'closing_price': '139',
#            'max_price': '143',
#            'min_price': '132',
#            'opening_price': '137',
#            'sell_price': '139',
#            'units_traded': '2198558.1505816',
#            'volume_1day': '2198558.1505816',
#            'volume_7day': '37868407.30703948'},
#  'ETZ': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '1.47',
#          'average_price': '276.0779',
#          'buy_price': '274',
#          'closing_price': '275',
#          'max_price': '288',
#          'min_price': '259',
#          'opening_price': '271',
#          'sell_price': '275',
#          'units_traded': '1206373.66826106',
#          'volume_1day': '1206373.66826106',
#          'volume_7day': '18915509.558454935344719535'},
#  'GNT': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '1.41',
#          'average_price': '71.246',
#          'buy_price': '71.6',
#          'closing_price': '71.7',
#          'max_price': '74',
#          'min_price': '67.8',
#          'opening_price': '70.7',
#          'sell_price': '71.7',
#          'units_traded': '779167.99549108',
#          'volume_1day': '779167.99549108',
#          'volume_7day': '4411726.934930940668473719'},
#  'GTO': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.37',
#          'average_price': '27.1194',
#          'buy_price': '26.5',
#          'closing_price': '26.6',
#          'max_price': '28.1',
#          'min_price': '25.6',
#          'opening_price': '26.5',
#          'sell_price': '26.6',
#          'units_traded': '1944468.30318549',
#          'volume_1day': '1944468.30318549',
#          'volume_7day': '19265988.24543589'},
#  'GXC': {'24H_fluctate': '64',
#          '24H_fluctate_rate': '3.47',
#          'average_price': '1872.7227',
#          'buy_price': '1890',
#          'closing_price': '1907',
#          'max_price': '2020',
#          'min_price': '1769',
#          'opening_price': '1843',
#          'sell_price': '1906',
#          'units_traded': '121385.57458958',
#          'volume_1day': '121385.57458958',
#          'volume_7day': '1134922.94236293'},
#  'HC': {'24H_fluctate': '5',
#         '24H_fluctate_rate': '0.13',
#         'average_price': '3613.4143',
#         'buy_price': '3587',
#         'closing_price': '3626',
#         'max_price': '3779',
#         'min_price': '3350',
#         'opening_price': '3621',
#         'sell_price': '3600',
#         'units_traded': '182307.36472842',
#         'volume_1day': '182307.36472842',
#         'volume_7day': '3997636.03440415'},
#  'HDAC': {'24H_fluctate': '-0.7',
#           '24H_fluctate_rate': '-2.31',
#           'average_price': '29.786',
#           'buy_price': '29.5',
#           'closing_price': '29.5',
#           'max_price': '30.7',
#           'min_price': '28.5',
#           'opening_price': '30.2',
#           'sell_price': '29.7',
#           'units_traded': '4650195.46331923',
#           'volume_1day': '4650195.46331923',
#           'volume_7day': '59853571.40833567'},
#  'HYC': {'24H_fluctate': '1.01',
#          '24H_fluctate_rate': '11.23',
#          'average_price': '9.7124',
#          'buy_price': '9.97',
#          'closing_price': '10',
#          'max_price': '10.8',
#          'min_price': '8.6',
#          'opening_price': '8.99',
#          'sell_price': '10',
#          'units_traded': '118338927.98764413',
#          'volume_1day': '118338927.98764413',
#          'volume_7day': '1003974621.155161406'},
#  'ICX': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '1.57',
#          'average_price': '322.6578',
#          'buy_price': '319',
#          'closing_price': '323',
#          'max_price': '336',
#          'min_price': '313',
#          'opening_price': '318',
#          'sell_price': '322',
#          'units_traded': '157483.21183617',
#          'volume_1day': '157483.21183617',
#          'volume_7day': '2809503.258503087014172863'},
#  'INS': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '401.266',
#          'buy_price': '394',
#          'closing_price': '399',
#          'max_price': '431',
#          'min_price': '378',
#          'opening_price': '399',
#          'sell_price': '399',
#          'units_traded': '252413.07150376',
#          'volume_1day': '252413.07150376',
#          'volume_7day': '7852130.1042482072'},
#  'IOST': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '10.7949',
#           'buy_price': '10.7',
#           'closing_price': '10.8',
#           'max_price': '11.2',
#           'min_price': '10.4',
#           'opening_price': '10.8',
#           'sell_price': '10.8',
#           'units_traded': '4823731.4400649',
#           'volume_1day': '4823731.4400649',
#           'volume_7day': '32541366.414743269544246365'},
#  'ITC': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-0.95',
#          'average_price': '314.3953',
#          'buy_price': '310',
#          'closing_price': '311',
#          'max_price': '325',
#          'min_price': '291',
#          'opening_price': '314',
#          'sell_price': '313',
#          'units_traded': '1323843.03416566',
#          'volume_1day': '1323843.03416566',
#          'volume_7day': '11142822.497097638135793641'},
#  'KNC': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '3.36',
#          'average_price': '210.4412',
#          'buy_price': '215',
#          'closing_price': '215',
#          'max_price': '220',
#          'min_price': '197',
#          'opening_price': '208',
#          'sell_price': '218',
#          'units_traded': '1075410.4479',
#          'volume_1day': '1075410.4479',
#          'volume_7day': '6243302.859673164906655786'},
#  'LAMB': {'24H_fluctate': '22',
#           '24H_fluctate_rate': '8.97',
#           'average_price': '265.4314',
#           'buy_price': '266',
#           'closing_price': '267',
#           'max_price': '290',
#           'min_price': '234',
#           'opening_price': '245',
#           'sell_price': '269',
#           'units_traded': '178676909.80211171',
#           'volume_1day': '178676909.80211171',
#           'volume_7day': '545452735.629713145241422553'},
#  'LBA': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.57',
#          'average_price': '24.8869',
#          'buy_price': '25',
#          'closing_price': '25',
#          'max_price': '26.5',
#          'min_price': '23',
#          'opening_price': '25.4',
#          'sell_price': '25.1',
#          'units_traded': '18083291.47438136',
#          'volume_1day': '18083291.47438136',
#          'volume_7day': '104037382.426520974422729763'},
#  'LINK': {'24H_fluctate': '-54',
#           '24H_fluctate_rate': '-1.20',
#           'average_price': '4399.845',
#           'buy_price': '4427',
#           'closing_price': '4427',
#           'max_price': '4643',
#           'min_price': '4003',
#           'opening_price': '4481',
#           'sell_price': '4428',
#           'units_traded': '388755.83202274',
#           'volume_1day': '388755.83202274',
#           'volume_7day': '3680809.442349125774885661'},
#  'LOOM': {'24H_fluctate': '0.2',
#           '24H_fluctate_rate': '0.27',
#           'average_price': '73.9567',
#           'buy_price': '73.2',
#           'closing_price': '73.2',
#           'max_price': '77.6',
#           'min_price': '72.2',
#           'opening_price': '73',
#           'sell_price': '73.9',
#           'units_traded': '341809.77960206',
#           'volume_1day': '341809.77960206',
#           'volume_7day': '3055792.053589397814881447'},
#  'LRC': {'24H_fluctate': '1.1',
#          '24H_fluctate_rate': '1.62',
#          'average_price': '68.9695',
#          'buy_price': '68.6',
#          'closing_price': '68.8',
#          'max_price': '73.2',
#          'min_price': '66',
#          'opening_price': '67.7',
#          'sell_price': '71.1',
#          'units_traded': '1612638.93949777',
#          'volume_1day': '1612638.93949777',
#          'volume_7day': '5887255.268280889613527602'},
#  'LTC': {'24H_fluctate': '5900',
#          '24H_fluctate_rate': '5.32',
#          'average_price': '116164.4293',
#          'buy_price': '116200',
#          'closing_price': '116600',
#          'max_price': '123700',
#          'min_price': '106200',
#          'opening_price': '110700',
#          'sell_price': '116400',
#          'units_traded': '76459.5948124',
#          'volume_1day': '76459.5948124',
#          'volume_7day': '254472.07317289'},
#  'MCO': {'24H_fluctate': '-25',
#          '24H_fluctate_rate': '-0.45',
#          'average_price': '5429.5812',
#          'buy_price': '5425',
#          'closing_price': '5425',
#          'max_price': '5605',
#          'min_price': '5105',
#          'opening_price': '5450',
#          'sell_price': '5485',
#          'units_traded': '39552.47126053',
#          'volume_1day': '39552.47126053',
#          'volume_7day': '272651.79175833'},
#  'MITH': {'24H_fluctate': '1',
#           '24H_fluctate_rate': '2.38',
#           'average_price': '43.0626',
#           'buy_price': '42.8',
#           'closing_price': '43',
#           'max_price': '44.6',
#           'min_price': '41.6',
#           'opening_price': '42',
#           'sell_price': '43',
#           'units_traded': '1639048.15635347',
#           'volume_1day': '1639048.15635347',
#           'volume_7day': '18824991.099588340204782777'},
#  'MIX': {'24H_fluctate': '1.7',
#          '24H_fluctate_rate': '2.69',
#          'average_price': '65.6086',
#          'buy_price': '64.7',
#          'closing_price': '64.7',
#          'max_price': '69.7',
#          'min_price': '60.6',
#          'opening_price': '63',
#          'sell_price': '66.3',
#          'units_traded': '3410668.35372855',
#          'volume_1day': '3410668.35372855',
#          'volume_7day': '17811935.600848375530458182'},
#  'MTL': {'24H_fluctate': '19',
#          '24H_fluctate_rate': '1.08',
#          'average_price': '1827.2432',
#          'buy_price': '1772',
#          'closing_price': '1772',
#          'max_price': '1939',
#          'min_price': '1620',
#          'opening_price': '1753',
#          'sell_price': '1777',
#          'units_traded': '152167.76932728',
#          'volume_1day': '152167.76932728',
#          'volume_7day': '630138.4334041'},
#  'NPXS': {'24H_fluctate': '0.02',
#           '24H_fluctate_rate': '2.85',
#           'average_price': '0.7119',
#           'buy_price': '0.71',
#           'closing_price': '0.72',
#           'max_price': '0.75',
#           'min_price': '0.66',
#           'opening_price': '0.7',
#           'sell_price': '0.72',
#           'units_traded': '853560547.34629117',
#           'volume_1day': '853560547.34629117',
#           'volume_7day': '4082135067.661288562804753231'},
#  'OCN': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '3.052',
#          'buy_price': '3.01',
#          'closing_price': '3.01',
#          'max_price': '3.2',
#          'min_price': '2.94',
#          'opening_price': '3.01',
#          'sell_price': '3.02',
#          'units_traded': '13337034.77447695',
#          'volume_1day': '13337034.77447695',
#          'volume_7day': '94557349.474380617549958181'},
#  'OMG': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '0.74',
#          'average_price': '1774.0111',
#          'buy_price': '1758',
#          'closing_price': '1759',
#          'max_price': '1846',
#          'min_price': '1652',
#          'opening_price': '1746',
#          'sell_price': '1772',
#          'units_traded': '411801.57958368',
#          'volume_1day': '411801.57958368',
#          'volume_7day': '3584200.085324294954659302'},
#  'ORBS': {'24H_fluctate': '-0.6',
#           '24H_fluctate_rate': '-2.23',
#           'average_price': '26.83',
#           'buy_price': '26.2',
#           'closing_price': '26.3',
#           'max_price': '27.6',
#           'min_price': '25.7',
#           'opening_price': '26.9',
#           'sell_price': '26.3',
#           'units_traded': '12324094.44604953',
#           'volume_1day': '12324094.44604953',
#           'volume_7day': '121818168.325235126462207993'},
#  'PAY': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.39',
#          'average_price': '246.6447',
#          'buy_price': '253',
#          'closing_price': '256',
#          'max_price': '273',
#          'min_price': '155',
#          'opening_price': '255',
#          'sell_price': '256',
#          'units_traded': '634382.3483713',
#          'volume_1day': '634382.3483713',
#          'volume_7day': '2254407.207612903717508885'},
#  'PIVX': {'24H_fluctate': '-6',
#           '24H_fluctate_rate': '-0.34',
#           'average_price': '1728.302',
#           'buy_price': '1709',
#           'closing_price': '1748',
#           'max_price': '1823',
#           'min_price': '1586',
#           'opening_price': '1754',
#           'sell_price': '1733',
#           'units_traded': '109719.88531034',
#           'volume_1day': '109719.88531034',
#           'volume_7day': '443679.77726748'},
#  'PLY': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.84',
#          'average_price': '11.9908',
#          'buy_price': '11.8',
#          'closing_price': '11.8',
#          'max_price': '12.5',
#          'min_price': '11.4',
#          'opening_price': '11.9',
#          'sell_price': '11.9',
#          'units_traded': '50763936.48299047',
#          'volume_1day': '50763936.48299047',
#          'volume_7day': '286410792.65808371'},
#  'POLY': {'24H_fluctate': '-0.8',
#           '24H_fluctate_rate': '-1.24',
#           'average_price': '64.4926',
#           'buy_price': '63.7',
#           'closing_price': '63.7',
#           'max_price': '67.4',
#           'min_price': '60.8',
#           'opening_price': '64.5',
#           'sell_price': '64.7',
#           'units_traded': '3767419.86076935',
#           'volume_1day': '3767419.86076935',
#           'volume_7day': '49120671.962907575680765539'},
#  'POWR': {'24H_fluctate': '-2.8',
#           '24H_fluctate_rate': '-3.07',
#           'average_price': '90.5769',
#           'buy_price': '87',
#           'closing_price': '88.2',
#           'max_price': '95',
#           'min_price': '86.2',
#           'opening_price': '91',
#           'sell_price': '87.6',
#           'units_traded': '1198230.1205738',
#           'volume_1day': '1198230.1205738',
#           'volume_7day': '6794594.95722228'},
#  'PPT': {'24H_fluctate': '168',
#          '24H_fluctate_rate': '5.76',
#          'average_price': '3013.6033',
#          'buy_price': '3085',
#          'closing_price': '3084',
#          'max_price': '3251',
#          'min_price': '2764',
#          'opening_price': '2916',
#          'sell_price': '3114',
#          'units_traded': '97112.86988449',
#          'volume_1day': '97112.86988449',
#          'volume_7day': '841720.751325'},
#  'PST': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.72',
#          'average_price': '140.8401',
#          'buy_price': '138',
#          'closing_price': '139',
#          'max_price': '146',
#          'min_price': '134',
#          'opening_price': '138',
#          'sell_price': '139',
#          'units_traded': '2139426.23343644',
#          'volume_1day': '2139426.23343644',
#          'volume_7day': '21693385.285289230351330192'},
#  'QTUM': {'24H_fluctate': '68',
#           '24H_fluctate_rate': '1.91',
#           'average_price': '3638.9661',
#           'buy_price': '3610',
#           'closing_price': '3619',
#           'max_price': '3822',
#           'min_price': '3425',
#           'opening_price': '3551',
#           'sell_price': '3619',
#           'units_traded': '441474.55899267',
#           'volume_1day': '441474.55899267',
#           'volume_7day': '3390134.74949988'},
#  'RDN': {'24H_fluctate': '-12',
#          '24H_fluctate_rate': '-1.33',
#          'average_price': '898.5887',
#          'buy_price': '884',
#          'closing_price': '887',
#          'max_price': '934',
#          'min_price': '840',
#          'opening_price': '899',
#          'sell_price': '893',
#          'units_traded': '130499.88471908',
#          'volume_1day': '130499.88471908',
#          'volume_7day': '1369656.567405500656495031'},
#  'REP': {'24H_fluctate': '130',
#          '24H_fluctate_rate': '0.73',
#          'average_price': '18085.8603',
#          'buy_price': '17760',
#          'closing_price': '17900',
#          'max_price': '18750',
#          'min_price': '17310',
#          'opening_price': '17770',
#          'sell_price': '17890',
#          'units_traded': '23202.45354248',
#          'volume_1day': '23202.45354248',
#          'volume_7day': '178512.379238450908894104'},
#  'RNT': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.25',
#          'average_price': '39.2553',
#          'buy_price': '39.5',
#          'closing_price': '39.6',
#          'max_price': '40.1',
#          'min_price': '37.6',
#          'opening_price': '39.7',
#          'sell_price': '39.6',
#          'units_traded': '1961213.04878638',
#          'volume_1day': '1961213.04878638',
#          'volume_7day': '24524473.152662428236649735'},
#  'ROM': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '25.00',
#          'average_price': '0.0441',
#          'buy_price': '0.04',
#          'closing_price': '0.05',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.04',
#          'sell_price': '0.05',
#          'units_traded': '1243753468.47888',
#          'volume_1day': '1243753468.47888',
#          'volume_7day': '10335020146.806846666666666665'},
#  'SALT': {'24H_fluctate': '-13',
#           '24H_fluctate_rate': '-7.14',
#           'average_price': '169.4786',
#           'buy_price': '169',
#           'closing_price': '169',
#           'max_price': '188',
#           'min_price': '146',
#           'opening_price': '182',
#           'sell_price': '170',
#           'units_traded': '5896009.38648536',
#           'volume_1day': '5896009.38648536',
#           'volume_7day': '8203183.82906201'},
#  'SNT': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '3.03',
#          'average_price': '23.6214',
#          'buy_price': '23.8',
#          'closing_price': '23.8',
#          'max_price': '25.3',
#          'min_price': '22.2',
#          'opening_price': '23.1',
#          'sell_price': '23.9',
#          'units_traded': '5359880.14507739',
#          'volume_1day': '5359880.14507739',
#          'volume_7day': '48493300.260067670549915006'},
#  'STEEM': {'24H_fluctate': '11',
#            '24H_fluctate_rate': '3.09',
#            'average_price': '367.4605',
#            'buy_price': '366',
#            'closing_price': '366',
#            'max_price': '388',
#            'min_price': '339',
#            'opening_price': '355',
#            'sell_price': '369',
#            'units_traded': '368314.93445735',
#            'volume_1day': '368314.93445735',
#            'volume_7day': '11555401.54009186'},
#  'STRAT': {'24H_fluctate': '-22',
#            '24H_fluctate_rate': '-1.63',
#            'average_price': '1329.249',
#            'buy_price': '1320',
#            'closing_price': '1320',
#            'max_price': '1407',
#            'min_price': '1250',
#            'opening_price': '1342',
#            'sell_price': '1329',
#            'units_traded': '130241.64321435',
#            'volume_1day': '130241.64321435',
#            'volume_7day': '1198323.48241222'},
#  'THETA': {'24H_fluctate': '5',
#            '24H_fluctate_rate': '4.20',
#            'average_price': '121.5373',
#            'buy_price': '123',
#            'closing_price': '124',
#            'max_price': '128',
#            'min_price': '112',
#            'opening_price': '119',
#            'sell_price': '124',
#            'units_traded': '3238807.21384565',
#            'volume_1day': '3238807.21384565',
#            'volume_7day': '19516608.231249042231665668'},
#  'TMTG': {'24H_fluctate': '0.06',
#           '24H_fluctate_rate': '2.92',
#           'average_price': '2.0959',
#           'buy_price': '2.1',
#           'closing_price': '2.11',
#           'max_price': '2.14',
#           'min_price': '2.05',
#           'opening_price': '2.05',
#           'sell_price': '2.11',
#           'units_traded': '31937955.31165211',
#           'volume_1day': '31937955.31165211',
#           'volume_7day': '280528922.760086657600944164'},
#  'TRUE': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '495.2018',
#           'buy_price': '490',
#           'closing_price': '490',
#           'max_price': '516',
#           'min_price': '462',
#           'opening_price': '490',
#           'sell_price': '491',
#           'units_traded': '379841.55548515',
#           'volume_1day': '379841.55548515',
#           'volume_7day': '4415754.069435121225126912'},
#  'TRX': {'24H_fluctate': '1.1',
#          '24H_fluctate_rate': '4.00',
#          'average_price': '28.5124',
#          'buy_price': '28.6',
#          'closing_price': '28.6',
#          'max_price': '29.8',
#          'min_price': '26.5',
#          'opening_price': '27.5',
#          'sell_price': '28.7',
#          'units_traded': '85133261.64571085',
#          'volume_1day': '85133261.64571085',
#          'volume_7day': '595207239.23866565'},
#  'VALOR': {'24H_fluctate': '-16',
#            '24H_fluctate_rate': '-0.69',
#            'average_price': '2311.6678',
#            'buy_price': '2284',
#            'closing_price': '2300',
#            'max_price': '2387',
#            'min_price': '2156',
#            'opening_price': '2316',
#            'sell_price': '2300',
#            'units_traded': '125346.4967146',
#            'volume_1day': '125346.4967146',
#            'volume_7day': '923461.756353090662850632'},
#  'VET': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '1.37',
#          'average_price': '7.4016',
#          'buy_price': '7.31',
#          'closing_price': '7.39',
#          'max_price': '7.74',
#          'min_price': '7.1',
#          'opening_price': '7.29',
#          'sell_price': '7.39',
#          'units_traded': '8019548.09770604',
#          'volume_1day': '8019548.09770604',
#          'volume_7day': '87959693.788885937714879226'},
#  'WAVES': {'24H_fluctate': '-21',
#            '24H_fluctate_rate': '-0.92',
#            'average_price': '2259.1896',
#            'buy_price': '2241',
#            'closing_price': '2257',
#            'max_price': '2349',
#            'min_price': '2120',
#            'opening_price': '2278',
#            'sell_price': '2262',
#            'units_traded': '108315.02197515',
#            'volume_1day': '108315.02197515',
#            'volume_7day': '1661811.17311153'},
#  'WAX': {'24H_fluctate': '2.8',
#          '24H_fluctate_rate': '4.86',
#          'average_price': '60.0805',
#          'buy_price': '60.2',
#          'closing_price': '60.4',
#          'max_price': '64.6',
#          'min_price': '52.1',
#          'opening_price': '57.6',
#          'sell_price': '60.4',
#          'units_traded': '7483966.05939861',
#          'volume_1day': '7483966.05939861',
#          'volume_7day': '19375404.81218233'},
#  'WET': {'24H_fluctate': '0.6',
#          '24H_fluctate_rate': '3.84',
#          'average_price': '16.4025',
#          'buy_price': '16.2',
#          'closing_price': '16.2',
#          'max_price': '17.8',
#          'min_price': '14.5',
#          'opening_price': '15.6',
#          'sell_price': '16.3',
#          'units_traded': '78815581.03508251',
#          'volume_1day': '78815581.03508251',
#          'volume_7day': '212970553.249549761718438068'},
#  'WTC': {'24H_fluctate': '-24',
#          '24H_fluctate_rate': '-1.03',
#          'average_price': '2311.3168',
#          'buy_price': '2306',
#          'closing_price': '2305',
#          'max_price': '2400',
#          'min_price': '2167',
#          'opening_price': '2329',
#          'sell_price': '2308',
#          'units_traded': '124346.31861647',
#          'volume_1day': '124346.31861647',
#          'volume_7day': '1890682.278754641204253752'},
#  'XEM': {'24H_fluctate': '0.19',
#          '24H_fluctate_rate': '0.22',
#          'average_price': '92.3035',
#          'buy_price': '90.2',
#          'closing_price': '90.1',
#          'max_price': '95.9',
#          'min_price': '85.1',
#          'opening_price': '89.9',
#          'sell_price': '91.9',
#          'units_traded': '780413.83243013',
#          'volume_1day': '780413.83243013',
#          'volume_7day': '10270691.91616213'},
#  'XLM': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '3.73',
#          'average_price': '112.0824',
#          'buy_price': '111',
#          'closing_price': '111',
#          'max_price': '116',
#          'min_price': '106',
#          'opening_price': '107',
#          'sell_price': '112',
#          'units_traded': '4571052.01515168',
#          'volume_1day': '4571052.01515168',
#          'volume_7day': '25345815.38784059'},
#  'XMR': {'24H_fluctate': '3600',
#          '24H_fluctate_rate': '3.94',
#          'average_price': '97548.2975',
#          'buy_price': '94650',
#          'closing_price': '94800',
#          'max_price': '99000',
#          'min_price': '88600',
#          'opening_price': '91200',
#          'sell_price': '94800',
#          'units_traded': '639057.82845367',
#          'volume_1day': '639057.82845367',
#          'volume_7day': '23130343.637551376427'},
#  'XRP': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '377.8794',
#          'buy_price': '374',
#          'closing_price': '375',
#          'max_price': '386',
#          'min_price': '363',
#          'opening_price': '375',
#          'sell_price': '375',
#          'units_traded': '92208732.36848096',
#          'volume_1day': '92208732.36848096',
#          'volume_7day': '586142361.71018816'},
#  'XVG': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '1.57',
#          'average_price': '13.2391',
#          'buy_price': '13.3',
#          'closing_price': '12.9',
#          'max_price': '14',
#          'min_price': '12.6',
#          'opening_price': '12.7',
#          'sell_price': '13.4',
#          'units_traded': '1953850.92898461',
#          'volume_1day': '1953850.92898461',
#          'volume_7day': '14468026.78519269'},
#  'ZEC': {'24H_fluctate': '-2200',
#          '24H_fluctate_rate': '-2.20',
#          'average_price': '99652.6005',
#          'buy_price': '97800',
#          'closing_price': '97800',
#          'max_price': '103700',
#          'min_price': '94350',
#          'opening_price': '100000',
#          'sell_price': '99000',
#          'units_traded': '1843.83032092',
#          'volume_1day': '1843.83032092',
#          'volume_7day': '16153.61988354'},
#  'ZIL': {'24H_fluctate': '0.09',
#          '24H_fluctate_rate': '0.61',
#          'average_price': '16.3604',
#          'buy_price': '16.4',
#          'closing_price': '16.4',
#          'max_price': '17.1',
#          'min_price': '15.4',
#          'opening_price': '16.3',
#          'sell_price': '16.5',
#          'units_traded': '8501569.39692841',
#          'volume_1day': '8501569.39692841',
#          'volume_7day': '51121646.742097211524'},
#  'ZRX': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '1.81',
#          'average_price': '279.6616',
#          'buy_price': '278',
#          'closing_price': '281',
#          'max_price': '289',
#          'min_price': '261',
#          'opening_price': '276',
#          'sell_price': '284',
#          'units_traded': '442259.18916286',
#          'volume_1day': '442259.18916286',
#          'volume_7day': '5233317.779918913734571648'},
#  'date': '1563528243343'}

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# %%
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

# %%
# Out:
# ['7번방의선물', '괴물', '도둑들', '베테랑', '아바타']
