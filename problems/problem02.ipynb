# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '-57',
#          '24H_fluctate_rate': '-17.86',
#          'average_price': '272.9768',
#          'buy_price': '256',
#          'closing_price': '262',
#          'max_price': '319',
#          'min_price': '243',
#          'opening_price': '319',
#          'sell_price': '262',
#          'units_traded': '2017725.8477242',
#          'volume_1day': '2017725.8477242',
#          'volume_7day': '12384039.718501153241433814'},
#  'ADA': {'24H_fluctate': '-16.1',
#          '24H_fluctate_rate': '-16.66',
#          'average_price': '85.3027',
#          'buy_price': '80.1',
#          'closing_price': '80.5',
#          'max_price': '97.7',
#          'min_price': '73',
#          'opening_price': '96.6',
#          'sell_price': '80.4',
#          'units_traded': '13991824.31009571',
#          'volume_1day': '13991824.31009571',
#          'volume_7day': '66426444.60109903'},
#  'AE': {'24H_fluctate': '-85',
#         '24H_fluctate_rate': '-16.00',
#         'average_price': '470.103',
#         'buy_price': '444',
#         'closing_price': '446',
#         'max_price': '536',
#         'min_price': '425',
#         'opening_price': '531',
#         'sell_price': '445',
#         'units_traded': '514239.59420944',
#         'volume_1day': '514239.59420944',
#         'volume_7day': '2676920.652852776820076997'},
#  'AMO': {'24H_fluctate': '-0.06',
#          '24H_fluctate_rate': '-9.52',
#          'average_price': '0.5838',
#          'buy_price': '0.56',
#          'closing_price': '0.57',
#          'max_price': '0.64',
#          'min_price': '0.53',
#          'opening_price': '0.63',
#          'sell_price': '0.57',
#          'units_traded': '339774264.83211162',
#          'volume_1day': '339774264.83211162',
#          'volume_7day': '2886945691.780363774142393379'},
#  'ANKR': {'24H_fluctate': '-1.3',
#           '24H_fluctate_rate': '-11.50',
#           'average_price': '10.4624',
#           'buy_price': '9.99',
#           'closing_price': '10',
#           'max_price': '11.3',
#           'min_price': '9.82',
#           'opening_price': '11.3',
#           'sell_price': '10',
#           'units_traded': '57436302.47662561',
#           'volume_1day': '57436302.47662561',
#           'volume_7day': '675045907.784228306127993'},
#  'APIS': {'24H_fluctate': '-0.13',
#           '24H_fluctate_rate': '-7.51',
#           'average_price': '1.5837',
#           'buy_price': '1.6',
#           'closing_price': '1.6',
#           'max_price': '1.76',
#           'min_price': '1.48',
#           'opening_price': '1.73',
#           'sell_price': '1.61',
#           'units_traded': '63027863.80526376',
#           'volume_1day': '63027863.80526376',
#           'volume_7day': '315756721.176219470695442557'},
#  'ARN': {'24H_fluctate': '-74',
#          '24H_fluctate_rate': '-14.20',
#          'average_price': '484.4164',
#          'buy_price': '447',
#          'closing_price': '447',
#          'max_price': '530',
#          'min_price': '446',
#          'opening_price': '521',
#          'sell_price': '453',
#          'units_traded': '306528.81695479',
#          'volume_1day': '306528.81695479',
#          'volume_7day': '2023676.41417332'},
#  'AUTO': {'24H_fluctate': '-0.19',
#           '24H_fluctate_rate': '-11.44',
#           'average_price': '1.5258',
#           'buy_price': '1.47',
#           'closing_price': '1.47',
#           'max_price': '1.69',
#           'min_price': '1.42',
#           'opening_price': '1.66',
#           'sell_price': '1.49',
#           'units_traded': '48268827.99967993',
#           'volume_1day': '48268827.99967993',
#           'volume_7day': '333563164.900902279130866446'},
#  'BAT': {'24H_fluctate': '-36',
#          '24H_fluctate_rate': '-12.81',
#          'average_price': '258.2175',
#          'buy_price': '242',
#          'closing_price': '245',
#          'max_price': '288',
#          'min_price': '238',
#          'opening_price': '281',
#          'sell_price': '245',
#          'units_traded': '1599383.96580857',
#          'volume_1day': '1599383.96580857',
#          'volume_7day': '9428430.603916323419644446'},
#  'BCD': {'24H_fluctate': '-218',
#          '24H_fluctate_rate': '-10.29',
#          'average_price': '1925.6972',
#          'buy_price': '1898',
#          'closing_price': '1900',
#          'max_price': '2189',
#          'min_price': '1790',
#          'opening_price': '2118',
#          'sell_price': '1900',
#          'units_traded': '143388.55336732',
#          'volume_1day': '143388.55336732',
#          'volume_7day': '1666238.331199'},
#  'BCH': {'24H_fluctate': '-33000',
#          '24H_fluctate_rate': '-8.96',
#          'average_price': '345834.0259',
#          'buy_price': '334500',
#          'closing_price': '335000',
#          'max_price': '369400',
#          'min_price': '329000',
#          'opening_price': '368000',
#          'sell_price': '335700',
#          'units_traded': '53809.10260837',
#          'volume_1day': '53809.10260837',
#          'volume_7day': '254063.16146976'},
#  'BHP': {'24H_fluctate': '-16',
#          '24H_fluctate_rate': '-0.92',
#          'average_price': '1757.9545',
#          'buy_price': '1706',
#          'closing_price': '1713',
#          'max_price': '1897',
#          'min_price': '1658',
#          'opening_price': '1729',
#          'sell_price': '1709',
#          'units_traded': '463480.67480967',
#          'volume_1day': '463480.67480967',
#          'volume_7day': '1644147.95161546'},
#  'BSV': {'24H_fluctate': '-19400',
#          '24H_fluctate_rate': '-12.72',
#          'average_price': '137958.3023',
#          'buy_price': '132800',
#          'closing_price': '133100',
#          'max_price': '153000',
#          'min_price': '127500',
#          'opening_price': '152500',
#          'sell_price': '133200',
#          'units_traded': '82368.74083923',
#          'volume_1day': '82368.74083923',
#          'volume_7day': '376141.2689565'},
#  'BTC': {'24H_fluctate': '-1947000',
#          '24H_fluctate_rate': '-15.10',
#          'average_price': '11673651.4989',
#          'buy_price': '10940000',
#          'closing_price': '10947000',
#          'max_price': '12894000',
#          'min_price': '10900000',
#          'opening_price': '12894000',
#          'sell_price': '10947000',
#          'units_traded': '20983.83619299',
#          'volume_1day': '20983.83619299',
#          'volume_7day': '97756.34308243'},
#  'BTG': {'24H_fluctate': '-2330',
#          '24H_fluctate_rate': '-7.77',
#          'average_price': '28344.4324',
#          'buy_price': '27600',
#          'closing_price': '27650',
#          'max_price': '30340',
#          'min_price': '27000',
#          'opening_price': '29980',
#          'sell_price': '27650',
#          'units_traded': '19640.89106388',
#          'volume_1day': '19640.89106388',
#          'volume_7day': '199270.50021003'},
#  'BTT': {'24H_fluctate': '-0.23',
#          '24H_fluctate_rate': '-17.03',
#          'average_price': '1.2147',
#          'buy_price': '1.12',
#          'closing_price': '1.12',
#          'max_price': '1.37',
#          'min_price': '1.09',
#          'opening_price': '1.35',
#          'sell_price': '1.15',
#          'units_traded': '345140010.6297519',
#          'volume_1day': '345140010.6297519',
#          'volume_7day': '1722263068.03096359'},
#  'BZNT': {'24H_fluctate': '-2.4',
#           '24H_fluctate_rate': '-10.71',
#           'average_price': '20.6943',
#           'buy_price': '19.9',
#           'closing_price': '20',
#           'max_price': '22.6',
#           'min_price': '19.6',
#           'opening_price': '22.4',
#           'sell_price': '20',
#           'units_traded': '8273974.28445683',
#           'volume_1day': '8273974.28445683',
#           'volume_7day': '63957886.728905963126640231'},
#  'CMT': {'24H_fluctate': '-11.8',
#          '24H_fluctate_rate': '-18.78',
#          'average_price': '53.8515',
#          'buy_price': '50.3',
#          'closing_price': '51',
#          'max_price': '63.5',
#          'min_price': '49.8',
#          'opening_price': '62.8',
#          'sell_price': '50.9',
#          'units_traded': '14516470.10203301',
#          'volume_1day': '14516470.10203301',
#          'volume_7day': '169999083.243374643991912187'},
#  'CON': {'24H_fluctate': '-2.3',
#          '24H_fluctate_rate': '-16.66',
#          'average_price': '12.4367',
#          'buy_price': '11.5',
#          'closing_price': '11.5',
#          'max_price': '14.4',
#          'min_price': '11.5',
#          'opening_price': '13.8',
#          'sell_price': '11.6',
#          'units_traded': '84347956.29908666',
#          'volume_1day': '84347956.29908666',
#          'volume_7day': '944305269.202351579685500479'},
#  'CTXC': {'24H_fluctate': '-92',
#           '24H_fluctate_rate': '-18.69',
#           'average_price': '417.6134',
#           'buy_price': '399',
#           'closing_price': '400',
#           'max_price': '500',
#           'min_price': '270',
#           'opening_price': '492',
#           'sell_price': '403',
#           'units_traded': '1303296.68373548',
#           'volume_1day': '1303296.68373548',
#           'volume_7day': '8174397.584005610576264594'},
#  'DAC': {'24H_fluctate': '0.15',
#          '24H_fluctate_rate': '2.61',
#          'average_price': '5.7735',
#          'buy_price': '5.77',
#          'closing_price': '5.88',
#          'max_price': '6.34',
#          'min_price': '5.21',
#          'opening_price': '5.73',
#          'sell_price': '5.93',
#          'units_traded': '87882507.82257074',
#          'volume_1day': '87882507.82257074',
#          'volume_7day': '495505527.11711370638023472'},
#  'DACC': {'24H_fluctate': '-0.02',
#           '24H_fluctate_rate': '-11.76',
#           'average_price': '0.154',
#           'buy_price': '0.14',
#           'closing_price': '0.15',
#           'max_price': '0.17',
#           'min_price': '0.14',
#           'opening_price': '0.17',
#           'sell_price': '0.15',
#           'units_traded': '791709320.32668826',
#           'volume_1day': '791709320.32668826',
#           'volume_7day': '3379945593.77687429'},
#  'DASH': {'24H_fluctate': '-28000',
#           '24H_fluctate_rate': '-17.48',
#           'average_price': '139607.4875',
#           'buy_price': '132200',
#           'closing_price': '132100',
#           'max_price': '160100',
#           'min_price': '130100',
#           'opening_price': '160100',
#           'sell_price': '136200',
#           'units_traded': '1862047.07172771',
#           'volume_1day': '1862047.07172771',
#           'volume_7day': '10631308.08895804'},
#  'ELF': {'24H_fluctate': '-27',
#          '24H_fluctate_rate': '-16.77',
#          'average_price': '140.4967',
#          'buy_price': '134',
#          'closing_price': '134',
#          'max_price': '162',
#          'min_price': '129',
#          'opening_price': '161',
#          'sell_price': '135',
#          'units_traded': '1343847.43561957',
#          'volume_1day': '1343847.43561957',
#          'volume_7day': '10575219.510221605211703553'},
#  'ENJ': {'24H_fluctate': '-25.7',
#          '24H_fluctate_rate': '-21.59',
#          'average_price': '101.4697',
#          'buy_price': '93.4',
#          'closing_price': '93.3',
#          'max_price': '119',
#          'min_price': '93.3',
#          'opening_price': '119',
#          'sell_price': '94.1',
#          'units_traded': '23062319.79392357',
#          'volume_1day': '23062319.79392357',
#          'volume_7day': '90023775.474113773511993687'},
#  'EOS': {'24H_fluctate': '-805',
#          '24H_fluctate_rate': '-15.75',
#          'average_price': '4529.4929',
#          'buy_price': '4305',
#          'closing_price': '4305',
#          'max_price': '5110',
#          'min_price': '4230',
#          'opening_price': '5110',
#          'sell_price': '4312',
#          'units_traded': '5512720.63826228',
#          'volume_1day': '5512720.63826228',
#          'volume_7day': '22327238.61112746'},
#  'ETC': {'24H_fluctate': '-930',
#          '24H_fluctate_rate': '-12.80',
#          'average_price': '6652.8165',
#          'buy_price': '6305',
#          'closing_price': '6330',
#          'max_price': '7265',
#          'min_price': '6295',
#          'opening_price': '7260',
#          'sell_price': '6325',
#          'units_traded': '212300.74205127',
#          'volume_1day': '212300.74205127',
#          'volume_7day': '970057.453057639993454676'},
#  'ETH': {'24H_fluctate': '-37400',
#          '24H_fluctate_rate': '-13.83',
#          'average_price': '246409.1872',
#          'buy_price': '232900',
#          'closing_price': '233000',
#          'max_price': '270700',
#          'min_price': '231100',
#          'opening_price': '270400',
#          'sell_price': '233000',
#          'units_traded': '162752.3746316',
#          'volume_1day': '162752.3746316',
#          'volume_7day': '712808.516666276281850419'},
#  'ETHOS': {'24H_fluctate': '-22',
#            '24H_fluctate_rate': '-14.19',
#            'average_price': '140.2988',
#            'buy_price': '131',
#            'closing_price': '133',
#            'max_price': '155',
#            'min_price': '127',
#            'opening_price': '155',
#            'sell_price': '133',
#            'units_traded': '3999135.51401299',
#            'volume_1day': '3999135.51401299',
#            'volume_7day': '48396812.73418808'},
#  'ETZ': {'24H_fluctate': '-54',
#          '24H_fluctate_rate': '-17.70',
#          'average_price': '271.5048',
#          'buy_price': '250',
#          'closing_price': '251',
#          'max_price': '306',
#          'min_price': '247',
#          'opening_price': '305',
#          'sell_price': '252',
#          'units_traded': '2219778.78346239',
#          'volume_1day': '2219778.78346239',
#          'volume_7day': '18510683.944463001011140234'},
#  'GNT': {'24H_fluctate': '-10.9',
#          '24H_fluctate_rate': '-14.34',
#          'average_price': '68.6819',
#          'buy_price': '65',
#          'closing_price': '65.1',
#          'max_price': '77.4',
#          'min_price': '62',
#          'opening_price': '76',
#          'sell_price': '65.3',
#          'units_traded': '807610.60848251',
#          'volume_1day': '807610.60848251',
#          'volume_7day': '5603404.604796524171097757'},
#  'GTO': {'24H_fluctate': '-4.3',
#          '24H_fluctate_rate': '-15.14',
#          'average_price': '25.7167',
#          'buy_price': '24.1',
#          'closing_price': '24.1',
#          'max_price': '29.1',
#          'min_price': '22.9',
#          'opening_price': '28.4',
#          'sell_price': '24.5',
#          'units_traded': '4414718.49946339',
#          'volume_1day': '4414718.49946339',
#          'volume_7day': '29086541.97610596'},
#  'GXC': {'24H_fluctate': '-183',
#          '24H_fluctate_rate': '-9.46',
#          'average_price': '1810.5211',
#          'buy_price': '1719',
#          'closing_price': '1750',
#          'max_price': '1933',
#          'min_price': '1674',
#          'opening_price': '1933',
#          'sell_price': '1750',
#          'units_traded': '146273.01511826',
#          'volume_1day': '146273.01511826',
#          'volume_7day': '1634454.87958557'},
#  'HC': {'24H_fluctate': '-713',
#         '24H_fluctate_rate': '-17.76',
#         'average_price': '3606.1236',
#         'buy_price': '3279',
#         'closing_price': '3300',
#         'max_price': '4019',
#         'min_price': '3300',
#         'opening_price': '4013',
#         'sell_price': '3300',
#         'units_traded': '382974.4282969',
#         'volume_1day': '382974.4282969',
#         'volume_7day': '4529255.07850753'},
#  'HDAC': {'24H_fluctate': '-2',
#           '24H_fluctate_rate': '-6.60',
#           'average_price': '30.8126',
#           'buy_price': '28.3',
#           'closing_price': '28.3',
#           'max_price': '34.1',
#           'min_price': '25',
#           'opening_price': '30.3',
#           'sell_price': '28.8',
#           'units_traded': '24996572.99768917',
#           'volume_1day': '24996572.99768917',
#           'volume_7day': '54162267.80018289'},
#  'HYC': {'24H_fluctate': '-1.97',
#          '24H_fluctate_rate': '-19.73',
#          'average_price': '8.8566',
#          'buy_price': '8.01',
#          'closing_price': '8.01',
#          'max_price': '10.1',
#          'min_price': '8',
#          'opening_price': '9.98',
#          'sell_price': '8.16',
#          'units_traded': '98614388.15250785',
#          'volume_1day': '98614388.15250785',
#          'volume_7day': '1314992223.935194989'},
#  'ICX': {'24H_fluctate': '-29',
#          '24H_fluctate_rate': '-8.40',
#          'average_price': '321.2312',
#          'buy_price': '310',
#          'closing_price': '316',
#          'max_price': '347',
#          'min_price': '300',
#          'opening_price': '345',
#          'sell_price': '317',
#          'units_traded': '396219.30640061',
#          'volume_1day': '396219.30640061',
#          'volume_7day': '3541002.85529161785240106'},
#  'INS': {'24H_fluctate': '-79',
#          '24H_fluctate_rate': '-17.79',
#          'average_price': '397.7941',
#          'buy_price': '366',
#          'closing_price': '365',
#          'max_price': '449',
#          'min_price': '360',
#          'opening_price': '444',
#          'sell_price': '376',
#          'units_traded': '475699.92156097',
#          'volume_1day': '475699.92156097',
#          'volume_7day': '8776234.6334069829'},
#  'IOST': {'24H_fluctate': '-1.4',
#           '24H_fluctate_rate': '-11.96',
#           'average_price': '10.4259',
#           'buy_price': '10.3',
#           'closing_price': '10.3',
#           'max_price': '11.7',
#           'min_price': '9.67',
#           'opening_price': '11.7',
#           'sell_price': '10.6',
#           'units_traded': '9721631.29670157',
#           'volume_1day': '9721631.29670157',
#           'volume_7day': '46199826.389886680264535102'},
#  'ITC': {'24H_fluctate': '-77',
#          '24H_fluctate_rate': '-20.92',
#          'average_price': '313.1182',
#          'buy_price': '291',
#          'closing_price': '291',
#          'max_price': '371',
#          'min_price': '276',
#          'opening_price': '368',
#          'sell_price': '300',
#          'units_traded': '1634094.00984239',
#          'volume_1day': '1634094.00984239',
#          'volume_7day': '22749728.97426280354080888'},
#  'KNC': {'24H_fluctate': '-39',
#          '24H_fluctate_rate': '-17.41',
#          'average_price': '193.5842',
#          'buy_price': '184',
#          'closing_price': '185',
#          'max_price': '225',
#          'min_price': '181',
#          'opening_price': '224',
#          'sell_price': '185',
#          'units_traded': '2238543.28690293',
#          'volume_1day': '2238543.28690293',
#          'volume_7day': '7166549.224874862807234699'},
#  'LAMB': {'24H_fluctate': '-30',
#           '24H_fluctate_rate': '-11.32',
#           'average_price': '252.4262',
#           'buy_price': '232',
#           'closing_price': '235',
#           'max_price': '284',
#           'min_price': '230',
#           'opening_price': '265',
#           'sell_price': '235',
#           'units_traded': '71490426.90681268',
#           'volume_1day': '71490426.90681268',
#           'volume_7day': '53228769.478112677252475587'},
#  'LBA': {'24H_fluctate': '-7.3',
#          '24H_fluctate_rate': '-24.25',
#          'average_price': '25.5804',
#          'buy_price': '22.8',
#          'closing_price': '22.8',
#          'max_price': '30.4',
#          'min_price': '22.8',
#          'opening_price': '30.1',
#          'sell_price': '23.1',
#          'units_traded': '27058299.00205011',
#          'volume_1day': '27058299.00205011',
#          'volume_7day': '85879399.451214703774017964'},
#  'LINK': {'24H_fluctate': '-843',
#           '24H_fluctate_rate': '-18.42',
#           'average_price': '4067.7981',
#           'buy_price': '3710',
#           'closing_price': '3732',
#           'max_price': '4606',
#           'min_price': '3600',
#           'opening_price': '4575',
#           'sell_price': '3732',
#           'units_traded': '428870.92784751',
#           'volume_1day': '428870.92784751',
#           'volume_7day': '5109455.956735249625255764'},
#  'LOOM': {'24H_fluctate': '-12.4',
#           '24H_fluctate_rate': '-14.92',
#           'average_price': '74.9401',
#           'buy_price': '70.7',
#           'closing_price': '70.7',
#           'max_price': '88.8',
#           'min_price': '68.5',
#           'opening_price': '83.1',
#           'sell_price': '72.8',
#           'units_traded': '754759.49391931',
#           'volume_1day': '754759.49391931',
#           'volume_7day': '4236499.918308981453506044'},
#  'LRC': {'24H_fluctate': '-7.9',
#          '24H_fluctate_rate': '-10.42',
#          'average_price': '67.6481',
#          'buy_price': '66.8',
#          'closing_price': '67.9',
#          'max_price': '76',
#          'min_price': '62.6',
#          'opening_price': '75.8',
#          'sell_price': '68.1',
#          'units_traded': '1095087.94079632',
#          'volume_1day': '1095087.94079632',
#          'volume_7day': '5753426.252861124180670225'},
#  'LTC': {'24H_fluctate': '-14300',
#          '24H_fluctate_rate': '-13.25',
#          'average_price': '98073.3519',
#          'buy_price': '93250',
#          'closing_price': '93600',
#          'max_price': '108100',
#          'min_price': '92300',
#          'opening_price': '107900',
#          'sell_price': '93650',
#          'units_traded': '32854.66770899',
#          'volume_1day': '32854.66770899',
#          'volume_7day': '194382.18323696'},
#  'MCO': {'24H_fluctate': '-715',
#          '24H_fluctate_rate': '-12.01',
#          'average_price': '5409.283',
#          'buy_price': '5190',
#          'closing_price': '5235',
#          'max_price': '6045',
#          'min_price': '4800',
#          'opening_price': '5950',
#          'sell_price': '5235',
#          'units_traded': '71042.82408252',
#          'volume_1day': '71042.82408252',
#          'volume_7day': '289366.41634616'},
#  'MITH': {'24H_fluctate': '-6.9',
#           '24H_fluctate_rate': '-14.77',
#           'average_price': '42.3839',
#           'buy_price': '39.8',
#           'closing_price': '39.8',
#           'max_price': '46.7',
#           'min_price': '39.5',
#           'opening_price': '46.7',
#           'sell_price': '40.5',
#           'units_traded': '5152429.04862354',
#           'volume_1day': '5152429.04862354',
#           'volume_7day': '19103391.223993007946493144'},
#  'MIX': {'24H_fluctate': '-5.1',
#          '24H_fluctate_rate': '-7.55',
#          'average_price': '60.6141',
#          'buy_price': '60.9',
#          'closing_price': '62.4',
#          'max_price': '67.5',
#          'min_price': '55',
#          'opening_price': '67.5',
#          'sell_price': '61.4',
#          'units_traded': '3336767.22691909',
#          'volume_1day': '3336767.22691909',
#          'volume_7day': '24350599.031400564094191795'},
#  'MTL': {'24H_fluctate': '-347',
#          '24H_fluctate_rate': '-17.60',
#          'average_price': '1781.0265',
#          'buy_price': '1570',
#          'closing_price': '1624',
#          'max_price': '2027',
#          'min_price': '1511',
#          'opening_price': '1971',
#          'sell_price': '1671',
#          'units_traded': '94638.41034795',
#          'volume_1day': '94638.41034795',
#          'volume_7day': '662824.79347114'},
#  'NPXS': {'24H_fluctate': '-0.13',
#           '24H_fluctate_rate': '-16.88',
#           'average_price': '0.7013',
#           'buy_price': '0.63',
#           'closing_price': '0.64',
#           'max_price': '0.77',
#           'min_price': '0.64',
#           'opening_price': '0.77',
#           'sell_price': '0.65',
#           'units_traded': '704319278.01326093',
#           'volume_1day': '704319278.01326093',
#           'volume_7day': '3451875009.881561024276730756'},
#  'OCN': {'24H_fluctate': '-0.15',
#          '24H_fluctate_rate': '-4.67',
#          'average_price': '2.9826',
#          'buy_price': '2.94',
#          'closing_price': '3.06',
#          'max_price': '3.33',
#          'min_price': '2.62',
#          'opening_price': '3.21',
#          'sell_price': '3.06',
#          'units_traded': '24210564.57941263',
#          'volume_1day': '24210564.57941263',
#          'volume_7day': '135262296.777848757929228558'},
#  'OMG': {'24H_fluctate': '-256',
#          '24H_fluctate_rate': '-13.95',
#          'average_price': '1676.786',
#          'buy_price': '1578',
#          'closing_price': '1578',
#          'max_price': '1834',
#          'min_price': '1555',
#          'opening_price': '1834',
#          'sell_price': '1588',
#          'units_traded': '644206.56888166',
#          'volume_1day': '644206.56888166',
#          'volume_7day': '3596701.356046739151023602'},
#  'ORBS': {'24H_fluctate': '-4.2',
#           '24H_fluctate_rate': '-14.48',
#           'average_price': '26.3316',
#           'buy_price': '24.8',
#           'closing_price': '24.8',
#           'max_price': '29.4',
#           'min_price': '24.1',
#           'opening_price': '29',
#           'sell_price': '24.9',
#           'units_traded': '29668680.27974575',
#           'volume_1day': '29668680.27974575',
#           'volume_7day': '138257002.849104690163878226'},
#  'PAY': {'24H_fluctate': '-27',
#          '24H_fluctate_rate': '-9.78',
#          'average_price': '252.4523',
#          'buy_price': '249',
#          'closing_price': '249',
#          'max_price': '276',
#          'min_price': '235',
#          'opening_price': '276',
#          'sell_price': '253',
#          'units_traded': '307555.69549214',
#          'volume_1day': '307555.69549214',
#          'volume_7day': '3074754.704109591894912887'},
#  'PIVX': {'24H_fluctate': '-224',
#           '24H_fluctate_rate': '-12.21',
#           'average_price': '1730.461',
#           'buy_price': '1620',
#           'closing_price': '1610',
#           'max_price': '1932',
#           'min_price': '1610',
#           'opening_price': '1834',
#           'sell_price': '1685',
#           'units_traded': '55563.42725369',
#           'volume_1day': '55563.42725369',
#           'volume_7day': '447311.0070364'},
#  'PLY': {'24H_fluctate': '-2.2',
#          '24H_fluctate_rate': '-16.29',
#          'average_price': '11.9861',
#          'buy_price': '11.2',
#          'closing_price': '11.3',
#          'max_price': '13.7',
#          'min_price': '11.1',
#          'opening_price': '13.5',
#          'sell_price': '11.3',
#          'units_traded': '55634407.4744871',
#          'volume_1day': '55634407.4744871',
#          'volume_7day': '317656455.282789833'},
#  'POLY': {'24H_fluctate': '-12.6',
#           '24H_fluctate_rate': '-17.54',
#           'average_price': '67.0303',
#           'buy_price': '59.2',
#           'closing_price': '59.2',
#           'max_price': '75.7',
#           'min_price': '59.2',
#           'opening_price': '71.8',
#           'sell_price': '59.5',
#           'units_traded': '12609569.08595404',
#           'volume_1day': '12609569.08595404',
#           'volume_7day': '51153639.344551978947398312'},
#  'POWR': {'24H_fluctate': '-10.9',
#           '24H_fluctate_rate': '-10.90',
#           'average_price': '92.0114',
#           'buy_price': '87.9',
#           'closing_price': '89.1',
#           'max_price': '101',
#           'min_price': '85',
#           'opening_price': '100',
#           'sell_price': '89.1',
#           'units_traded': '820855.47997081',
#           'volume_1day': '820855.47997081',
#           'volume_7day': '7799242.31807427'},
#  'PPT': {'24H_fluctate': '-646',
#          '24H_fluctate_rate': '-18.74',
#          'average_price': '3041.345',
#          'buy_price': '2767',
#          'closing_price': '2800',
#          'max_price': '3446',
#          'min_price': '2800',
#          'opening_price': '3446',
#          'sell_price': '2845',
#          'units_traded': '112511.89201706',
#          'volume_1day': '112511.89201706',
#          'volume_7day': '1389710.77284445'},
#  'PST': {'24H_fluctate': '-17',
#          '24H_fluctate_rate': '-11.48',
#          'average_price': '140.1143',
#          'buy_price': '131',
#          'closing_price': '131',
#          'max_price': '153',
#          'min_price': '131',
#          'opening_price': '148',
#          'sell_price': '132',
#          'units_traded': '4589825.72466304',
#          'volume_1day': '4589825.72466304',
#          'volume_7day': '24333292.811044984333900872'},
#  'QTUM': {'24H_fluctate': '-691',
#           '24H_fluctate_rate': '-17.63',
#           'average_price': '3461.8169',
#           'buy_price': '3212',
#           'closing_price': '3228',
#           'max_price': '3919',
#           'min_price': '3137',
#           'opening_price': '3919',
#           'sell_price': '3232',
#           'units_traded': '785301.19291816',
#           'volume_1day': '785301.19291816',
#           'volume_7day': '4159140.53698243'},
#  'RDN': {'24H_fluctate': '-135',
#          '24H_fluctate_rate': '-13.70',
#          'average_price': '894.1562',
#          'buy_price': '841',
#          'closing_price': '850',
#          'max_price': '993',
#          'min_price': '820',
#          'opening_price': '985',
#          'sell_price': '850',
#          'units_traded': '142251.14821996',
#          'volume_1day': '142251.14821996',
#          'volume_7day': '1860728.437356457697930111'},
#  'REP': {'24H_fluctate': '-3530',
#          '24H_fluctate_rate': '-17.31',
#          'average_price': '18111.2424',
#          'buy_price': '16860',
#          'closing_price': '16860',
#          'max_price': '20980',
#          'min_price': '16110',
#          'opening_price': '20390',
#          'sell_price': '16870',
#          'units_traded': '31985.89493939',
#          'volume_1day': '31985.89493939',
#          'volume_7day': '199352.242122922145573423'},
#  'RNT': {'24H_fluctate': '-3.5',
#          '24H_fluctate_rate': '-8.39',
#          'average_price': '39.1229',
#          'buy_price': '37.8',
#          'closing_price': '38.2',
#          'max_price': '42.1',
#          'min_price': '36.9',
#          'opening_price': '41.7',
#          'sell_price': '38.1',
#          'units_traded': '4279456.56789434',
#          'volume_1day': '4279456.56789434',
#          'volume_7day': '31482913.482982383345040979'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.0445',
#          'buy_price': '0.04',
#          'closing_price': '0.04',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.04',
#          'sell_price': '0.05',
#          'units_traded': '2079798658.26466',
#          'volume_1day': '2079798658.26466',
#          'volume_7day': '20190914725.694500000000000002'},
#  'SALT': {'24H_fluctate': '-34',
#           '24H_fluctate_rate': '-16.26',
#           'average_price': '187.9732',
#           'buy_price': '174',
#           'closing_price': '175',
#           'max_price': '209',
#           'min_price': '167',
#           'opening_price': '209',
#           'sell_price': '175',
#           'units_traded': '385167.87371624',
#           'volume_1day': '385167.87371624',
#           'volume_7day': '2792582.7552232'},
#  'SNT': {'24H_fluctate': '-3.3',
#          '24H_fluctate_rate': '-13.25',
#          'average_price': '22.5019',
#          'buy_price': '21.6',
#          'closing_price': '21.6',
#          'max_price': '25.2',
#          'min_price': '21.2',
#          'opening_price': '24.9',
#          'sell_price': '22',
#          'units_traded': '8656990.51590756',
#          'volume_1day': '8656990.51590756',
#          'volume_7day': '57632769.089657126382721397'},
#  'STEEM': {'24H_fluctate': '-52',
#            '24H_fluctate_rate': '-13.16',
#            'average_price': '353.9465',
#            'buy_price': '342',
#            'closing_price': '343',
#            'max_price': '400',
#            'min_price': '329',
#            'opening_price': '395',
#            'sell_price': '343',
#            'units_traded': '755085.36962448',
#            'volume_1day': '755085.36962448',
#            'volume_7day': '11930876.85884809'},
#  'STRAT': {'24H_fluctate': '-230',
#            '24H_fluctate_rate': '-15.74',
#            'average_price': '1315.3143',
#            'buy_price': '1231',
#            'closing_price': '1231',
#            'max_price': '1484',
#            'min_price': '1212',
#            'opening_price': '1461',
#            'sell_price': '1256',
#            'units_traded': '203122.52102959',
#            'volume_1day': '203122.52102959',
#            'volume_7day': '1571477.85529359'},
#  'THETA': {'24H_fluctate': '-12',
#            '24H_fluctate_rate': '-10.34',
#            'average_price': '112.4102',
#            'buy_price': '102',
#            'closing_price': '104',
#            'max_price': '125',
#            'min_price': '95.5',
#            'opening_price': '116',
#            'sell_price': '104',
#            'units_traded': '5696794.07451996',
#            'volume_1day': '5696794.07451996',
#            'volume_7day': '10926689.304411905561123318'},
#  'TMTG': {'24H_fluctate': '-0.17',
#           '24H_fluctate_rate': '-7.83',
#           'average_price': '2.0501',
#           'buy_price': '1.98',
#           'closing_price': '2',
#           'max_price': '2.2',
#           'min_price': '1.96',
#           'opening_price': '2.17',
#           'sell_price': '2',
#           'units_traded': '66136131.71622421',
#           'volume_1day': '66136131.71622421',
#           'volume_7day': '333720449.792241356603143452'},
#  'TRUE': {'24H_fluctate': '-80',
#           '24H_fluctate_rate': '-14.81',
#           'average_price': '486.3045',
#           'buy_price': '460',
#           'closing_price': '460',
#           'max_price': '559',
#           'min_price': '441',
#           'opening_price': '540',
#           'sell_price': '462',
#           'units_traded': '357217.5618136',
#           'volume_1day': '357217.5618136',
#           'volume_7day': '4690150.808735411485775569'},
#  'TRX': {'24H_fluctate': '-4.4',
#          '24H_fluctate_rate': '-15.22',
#          'average_price': '26.0191',
#          'buy_price': '24.4',
#          'closing_price': '24.5',
#          'max_price': '29',
#          'min_price': '24',
#          'opening_price': '28.9',
#          'sell_price': '24.6',
#          'units_traded': '146411186.00419121',
#          'volume_1day': '146411186.00419121',
#          'volume_7day': '656625164.89129649'},
#  'VALOR': {'24H_fluctate': '-425',
#            '24H_fluctate_rate': '-16.67',
#            'average_price': '2277.7243',
#            'buy_price': '2124',
#            'closing_price': '2124',
#            'max_price': '2567',
#            'min_price': '2124',
#            'opening_price': '2549',
#            'sell_price': '2162',
#            'units_traded': '173898.28289016',
#            'volume_1day': '173898.28289016',
#            'volume_7day': '951311.36178589396098895'},
#  'VET': {'24H_fluctate': '-0.54',
#          '24H_fluctate_rate': '-7.22',
#          'average_price': '7.0828',
#          'buy_price': '6.85',
#          'closing_price': '6.93',
#          'max_price': '7.69',
#          'min_price': '6.82',
#          'opening_price': '7.47',
#          'sell_price': '7.01',
#          'units_traded': '12209243.82124955',
#          'volume_1day': '12209243.82124955',
#          'volume_7day': '133471174.954280302021541062'},
#  'WAVES': {'24H_fluctate': '-495',
#            '24H_fluctate_rate': '-19.20',
#            'average_price': '2314.7204',
#            'buy_price': '2104',
#            'closing_price': '2083',
#            'max_price': '2616',
#            'min_price': '2035',
#            'opening_price': '2578',
#            'sell_price': '2143',
#            'units_traded': '238281.83528726',
#            'volume_1day': '238281.83528726',
#            'volume_7day': '1612359.37186793'},
#  'WAX': {'24H_fluctate': '-12',
#          '24H_fluctate_rate': '-18.69',
#          'average_price': '57.18',
#          'buy_price': '52.2',
#          'closing_price': '52.2',
#          'max_price': '64.2',
#          'min_price': '52.1',
#          'opening_price': '64.2',
#          'sell_price': '53',
#          'units_traded': '2426953.62815758',
#          'volume_1day': '2426953.62815758',
#          'volume_7day': '15393681.98555398'},
#  'WET': {'24H_fluctate': '-1.7',
#          '24H_fluctate_rate': '-11.33',
#          'average_price': '13.6592',
#          'buy_price': '13.3',
#          'closing_price': '13.3',
#          'max_price': '15.1',
#          'min_price': '12.6',
#          'opening_price': '15',
#          'sell_price': '13.4',
#          'units_traded': '21027160.53054231',
#          'volume_1day': '21027160.53054231',
#          'volume_7day': '140629388.602914906861631606'},
#  'WTC': {'24H_fluctate': '-452',
#          '24H_fluctate_rate': '-17.29',
#          'average_price': '2362.6691',
#          'buy_price': '2157',
#          'closing_price': '2161',
#          'max_price': '2650',
#          'min_price': '2161',
#          'opening_price': '2613',
#          'sell_price': '2160',
#          'units_traded': '200790.82794539',
#          'volume_1day': '200790.82794539',
#          'volume_7day': '4622051.481408002033857406'},
#  'XEM': {'24H_fluctate': '-12.8',
#          '24H_fluctate_rate': '-13.00',
#          'average_price': '88.0373',
#          'buy_price': '84.2',
#          'closing_price': '85.6',
#          'max_price': '99.5',
#          'min_price': '75.2',
#          'opening_price': '98.4',
#          'sell_price': '85',
#          'units_traded': '1622454.82639681',
#          'volume_1day': '1622454.82639681',
#          'volume_7day': '12699250.33332501'},
#  'XLM': {'24H_fluctate': '-9',
#          '24H_fluctate_rate': '-8.03',
#          'average_price': '104.5502',
#          'buy_price': '103',
#          'closing_price': '103',
#          'max_price': '112',
#          'min_price': '100',
#          'opening_price': '112',
#          'sell_price': '105',
#          'units_traded': '4344433.71178842',
#          'volume_1day': '4344433.71178842',
#          'volume_7day': '25479057.97090938'},
#  'XMR': {'24H_fluctate': '-12350',
#          '24H_fluctate_rate': '-12.40',
#          'average_price': '88877.587',
#          'buy_price': '86350',
#          'closing_price': '87200',
#          'max_price': '99900',
#          'min_price': '84900',
#          'opening_price': '99550',
#          'sell_price': '86900',
#          'units_traded': '3835992.94516138',
#          'volume_1day': '3835992.94516138',
#          'volume_7day': '22779744.701996576567'},
#  'XRP': {'24H_fluctate': '-19',
#          '24H_fluctate_rate': '-5.05',
#          'average_price': '362.1387',
#          'buy_price': '357',
#          'closing_price': '357',
#          'max_price': '381',
#          'min_price': '350',
#          'opening_price': '376',
#          'sell_price': '358',
#          'units_traded': '99830999.05993235',
#          'volume_1day': '99830999.05993235',
#          'volume_7day': '704126012.03509189'},
#  'XVG': {'24H_fluctate': '-2.2',
#          '24H_fluctate_rate': '-14.86',
#          'average_price': '12.7357',
#          'buy_price': '12.6',
#          'closing_price': '12.6',
#          'max_price': '14.8',
#          'min_price': '10.3',
#          'opening_price': '14.8',
#          'sell_price': '13',
#          'units_traded': '2737035.89223622',
#          'volume_1day': '2737035.89223622',
#          'volume_7day': '21357341.50416866'},
#  'ZEC': {'24H_fluctate': '-17800',
#          '24H_fluctate_rate': '-16.07',
#          'average_price': '98259.5172',
#          'buy_price': '92200',
#          'closing_price': '92900',
#          'max_price': '112500',
#          'min_price': '89000',
#          'opening_price': '110700',
#          'sell_price': '92900',
#          'units_traded': '3187.20591947',
#          'volume_1day': '3187.20591947',
#          'volume_7day': '17810.65394549'},
#  'ZIL': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-5.95',
#          'average_price': '16.004',
#          'buy_price': '15.8',
#          'closing_price': '15.8',
#          'max_price': '17',
#          'min_price': '15.1',
#          'opening_price': '16.8',
#          'sell_price': '15.9',
#          'units_traded': '10179039.53572857',
#          'volume_1day': '10179039.53572857',
#          'volume_7day': '64532678.247558268133'},
#  'ZRX': {'24H_fluctate': '-57',
#          '24H_fluctate_rate': '-18.50',
#          'average_price': '273.9186',
#          'buy_price': '250',
#          'closing_price': '251',
#          'max_price': '312',
#          'min_price': '251',
#          'opening_price': '308',
#          'sell_price': '253',
#          'units_traded': '1216451.42641379',
#          'volume_1day': '1216451.42641379',
#          'volume_7day': '5705082.710338027342227037'},
#  'date': '1563364045417'}

# %%
# for key,value in data.items():    
#     if type(value) == type(dict()):
#         max_price = float(value['max_price'])
#         min_price = float(value['min_price'])
#         opening_price = float(value['opening_price'])
#         price_range = max_price - min_price
#         if opening_price + price_range > max_price:
#             print('상승장')
#         else:
#             print('하락장')
#     else:
#         continue

# 상승장 확인(개별 코인)
# def gazua(token):
def gazua(op, minp, maxp):
    if op + (maxp - minp) > maxp:
        return'상승장'
    else:
        return'하락장'

# print(gazua(12003000, 11341000, 11000000, 13000000))
            
# 시장 전체 데이터    
def check_gazua(data):
    # 모든 토큰 이름: 상승장 or 하락장
    # gazua()를 활용
    # result = {'BTC': '하락장', 'ETH': '하락장', ....}
    result = {}
    for key,value in data.items():    
        if type(value) == type(dict()):
            max_price = float(value['max_price'])
            min_price = float(value['min_price'])
            opening_price = float(value['opening_price']) 
            result[key] = gazua(opening_price, min_price, max_price)    
    return result
print(check_gazua(data))
# Out:
# {'BTC': '상승장', 'ETH': '상승장', 'DASH': '상승장', 'LTC': '상승장', 'ETC': '상승장', 'XRP': '상승장', 'BCH': '상승장', 'XMR': '상승장', 'ZEC': '상승장', 'QTUM': '상승장', 'BTG': '상승장', 'EOS': '상승장', 'ICX': '상승장', 'VET': '상승장', 'TRX': '상승장', 'ELF': '상승장', 'MITH': '상승장', 'MCO': '상승장', 'OMG': '상승장', 'KNC': '상승장', 'GNT': '상승장', 'ZIL': '상승장', 'ETHOS': '상승장', 'PAY': '상승장', 'WAX': '상승장', 'POWR': '상승장', 'LRC': '상승장', 'GTO': '상승장', 'STEEM': '상승장', 'STRAT': '상승장', 'ZRX': '상승장', 'REP': '상승장', 'AE': '상승장', 'XEM': '상승장', 'SNT': '상승장', 'ADA': '상승장', 'PPT': '상승장', 'CTXC': '상승장', 'CMT': '상승장', 'THETA': '상승장', 'WTC': '상승장', 'ITC': '상승장', 'TRUE': '상승장', 'ABT': '상승장', 'RNT': '상승장', 'PLY': '상승장', 'WAVES': '상승장', 'LINK': '상승장', 'ENJ': '상승장', 'PST': '상승장', 'SALT': '상승장', 'RDN': '상승장', 'LOOM': '상승장', 'PIVX': '상승장', 'INS': '상승장', 'BCD': '상승장', 'BZNT': '상승장', 'XLM': '상승장', 'OCN': '상승장', 'BSV': '상승장', 'TMTG': '상승장', 'BAT': '상승장', 'WET': '상승장', 'XVG': '상승장', 'IOST': '상승장', 'POLY': '상승장', 'HC': '상승장', 'ROM': '하락장', 'AMO': '상승장', 'ETZ': '상승장', 'ARN': '상승장', 'APIS': '상승장', 'MTL': '상승장', 'DACC': '상승장', 'DAC': '상승장', 'BHP': '상승장', 'BTT': '상승장', 'HDAC': '상승장', 'NPXS': '상승장', 'AUTO': '상승장', 'GXC': '상승장', 'ORBS': '상승장', 'VALOR': '상승장', 'CON': '상승장', 'ANKR': '상승장', 'MIX': '상승장', 'HYC': '상승장', 'LBA': '상승장', 'LAMB': '상승장'}

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}

# %%
for i in student.values():
    ave = sum(student.values())/len(student)
print(ave)
# Out:
# 83.25

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# %%
bt_dict = {
    'A':0,
    'B':0,
    'O':0,
    'AB':0
}

for bt in blood:
    bt_dict[bt] += 1
print(bt_dict)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

# %%
UBD = 172212

def UBD_filter(movies):
    UBDs = []
    for key, values in movies.items():
        if values/UBD < 80:
            UBDs.append(key)
    return UBDs        
UBD_filter(movies)
# Out:
# ['7번방의선물', '괴물', '도둑들', '베테랑', '아바타']
